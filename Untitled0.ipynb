# %% [markdown]
# <a href="https://colab.research.google.com/github/BlueLan-code/ytp-demo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# 手動建立一個 3x2 的 2D Tensor
# 每一列 (row) 代表一個學生，每一欄 (column) 代表一個科目
grades_2d = torch.tensor([
    [85.3, 92.2],
    [70.6, 65.2],
    [99.1, 88.6]
])

print("--- 2D Tensor (3x2) ---")
print(grades_2d)
print(f"維度 (ndimension): {grades_2d.ndimension()}") # 會顯示 2
print(f"形狀 (shape): {grades_2d.shape}")             # 會顯示 [3, 2]
# Out:
# --- 2D Tensor (3x2) ---
# tensor([[85.3000, 92.2000],
#         [70.6000, 65.2000],
#         [99.1000, 88.6000]])
# 維度 (ndimension): 2
# 形狀 (shape): torch.Size([3, 2])

# %%
# 手動建立一個 2x3x2 的 3D Tensor
# 結構：[班級數, 學生數, 科目數]
school_3d = torch.tensor([
    [ # 第一班
        [85.0, 92.0],
        [70.0, 65.0],
        [99.0, 88.0]
    ],
    [ # 第二班
        [60.0, 72.0],
        [88.0, 81.0],
        [75.0, 90.0]
    ]
])

print("\n--- 3D Tensor (2x3x2) ---")
print(school_3d)
print(f"維度 (ndimension): {school_3d.ndimension()}") # 會顯示 3
print(f"形狀 (shape): {school_3d.shape}")             # torch.Size([2, 3, 2])
# Out:
# --- 3D Tensor (2x3x2) ---
# tensor([[[85., 92.],
#          [70., 65.],
#          [99., 88.]],
#
#         [[60., 72.],
#          [88., 81.],
#          [75., 90.]]])
# 維度 (ndimension): 3
# 形狀 (shape): torch.Size([2, 3, 2])

# %%
# 檢查是否有 GPU (CUDA)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"目前使用的設備是: {device}")

# 建立一個 Tensor 預設是在 CPU 上
x = torch.ones(3, 3)

# 移動到 GPU
x_gpu = x.to(device)

print(f"x 的位置: {x.device}")
print(f"x_gpu 的位置: {x_gpu.device}")
# Out:
# 目前使用的設備是: cuda
# x 的位置: cpu
# x_gpu 的位置: cuda:0

# %%
import cv2 # opencv
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount("/content/drive")


path = "/content/drive/MyDrive/ytp/bruce-barrow-Nm9stZybikM-unsplash.jpg"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image = cv2.imread(path)
print(type(image))
print(image.shape) # h, w, c
print(image)
# Out:
# <class 'numpy.ndarray'>
# (2433, 3637, 3)
# [[[240 238 237]
#   [243 241 240]
#   [243 241 240]
#   ...
#   [242 237 238]
#   [241 236 237]
#   [240 235 236]]
#
#  [[243 241 240]
#   [244 242 241]
#   [242 240 239]
#   ...
#   [242 237 238]
#   [242 237 238]
#   [243 238 239]]
#
#  [[245 243 242]
#   [245 243 242]
#   [242 240 239]
#   ...
#   [241 236 237]
#   [242 237 238]
#   [245 240 241]]
#
#  ...
#
#  [[ 43  50  53]
#   [ 44  51  54]
#   [ 49  58  61]
#   ...
#   [121 125 136]
#   [117 125 138]
#   [114 127 143]]
#
#  [[ 38  46  53]
#   [ 36  45  49]
#   [ 52  61  65]
#   ...
#   [138 143 152]
#   [127 136 146]
#   [118 129 143]]
#
#  [[ 42  51  60]
#   [ 45  54  63]
#   [ 53  63  70]
#   ...
#   [134 144 151]
#   [129 140 148]
#   [124 134 144]]]

# %%
plt.imshow(image) # cv2 (B, G, R)
plt.show()

# %%
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()
